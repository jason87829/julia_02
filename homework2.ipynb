# %%
swordman =  Dict("HP" => 100,"SP" => 50 ,"ATK" => 35, "DEF" =>25)
# Out:
# Dict{String,Int64} with 4 entries:
#   "HP"  => 100
#   "ATK" => 35
#   "SP"  => 50
#   "DEF" => 25

# %%
wizard =  Dict("HP" => 100,"SP" => 100 ,"ATK" => 50, "DEF" =>10)
# Out:
# Dict{String,Int64} with 4 entries:
#   "HP"  => 100
#   "ATK" => 50
#   "SP"  => 100
#   "DEF" => 10

# %%
swordman["HP"] = swordman["HP"] - 40
# Out:
# 460

# %%
WHP = wizard["HP"]
WSP = wizard["SP"]
WATK = wizard["ATK"]
WDEF = wizard["DEF"]
SHP = swordman["HP"]
SSP = swordman["SP"]
SATK = swordman["ATK"]
SDEF = swordman["DEF"]
# Out:
# 25

# %%
function fight1() 
    WHP = wizard["HP"]
    WSP = wizard["SP"]
    WATK = wizard["ATK"]
    WDEF = wizard["DEF"]
    SHP = swordman["HP"]
    SSP = swordman["SP"]
    SATK = swordman["ATK"]
    SDEF = swordman["DEF"]
       WHP = WHP - (SATK - WDEF ) * 0.8 
       SHP = SHP - (WATK - SDEF ) * 0.8 
end
# Out:
# fight1 (generic function with 1 method)

# %%
function fight2() 
    WHP = wizard["HP"]
    WSP = wizard["SP"]
    WATK = wizard["ATK"]
    WDEF = wizard["DEF"]
    SHP = swordman["HP"]
    SSP = swordman["SP"]
    SATK = swordman["ATK"]
    SDEF = swordman["DEF"]
    if F == 1
       if SSP > 0
           SSP = SSP - 20
           WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
           SHP = SHP - (WATK - SDEF ) * 0.8 
       else
           WHP = WHP - (SATK - WDEF ) * 0.8 
           SHP = SHP - (WATK - SDEF ) * 0.8 
       end
    elseif F == 0
       if SSP > 0
           SHP = SHP - (WATK - SDEF ) * 0.8 
           SSP = SSP - 20
           WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
       else
           SHP = SHP - (WATK - SDEF ) * 0.8 
           WHP = WHP - (SATK - WDEF ) * 0.8 
       end
    end
end
# Out:
# fight2 (generic function with 1 method)

# %%
function fight3() 
    WHP = wizard["HP"]
    WSP = wizard["SP"]
    WATK = wizard["ATK"]
    WDEF = wizard["DEF"]
    SHP = swordman["HP"]
    SSP = swordman["SP"]
    SATK = swordman["ATK"]
    SDEF = swordman["DEF"]
    if F == 1
       if WSP > 0
           WHP = WHP - (SATK - WDEF ) * 0.8 
           WSP = WSP - 20
           SATK2 = SATK*0.25
           SATK = SATK - SATK2
           WATK = WATK + SATK2
           SATK3 = SATK
           SATK = SDEF
           SDEF = SATK3
           SHP = SHP - (WATK - SDEF ) * 0.8 
       else
           WHP = WHP - (SATK - WDEF ) * 0.8 
           SHP = SHP - (WATK - SDEF ) * 0.8
       end
    elseif F == 0
       if WSP > 0
           WSP = WSP - 20
           SATK2 = SATK*0.25
           SATK = SATK - SATK2
           WATK = WATK + SATK2
           SATK3 = SATK
           SATK = SDEF
           SDEF = SATK3
           SHP = SHP - (WATK - SDEF ) * 0.8 
           WHP = WHP - (SATK - WDEF ) * 0.8 
       else
           SHP = SHP - (WATK - SDEF ) * 0.8
           WHP = WHP - (SATK - WDEF ) * 0.8 
        end
    end
end
# Out:
# fight3 (generic function with 1 method)

# %%
function fight4()
    WHP = wizard["HP"]
    WSP = wizard["SP"]
    WATK = wizard["ATK"]
    WDEF = wizard["DEF"]
    SHP = swordman["HP"]
    SSP = swordman["SP"]
    SATK = swordman["ATK"]
    SDEF = swordman["DEF"]
    if F ==1  
        if WSP > 0 && SSP > 0
            SSP = SSP - 20
            WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
            WSP = WSP - 20
            SATK2 = SATK*0.25
            SATK = SATK - SATK2
            WATK = WATK + SATK2
            SATK3 = SATK
            SATK = SDEF
            SDEF = SATK3
            SHP = SHP - (WATK - SDEF ) * 0.8 
        elseif WSP < 0 && SSP > 0
            SSP = SSP - 20
            WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
            SHP = SHP - (WATK - SDEF ) * 0.8
        elseif WSP > 0 && SSP < 0
            WSP = WSP - 20
            SATK2 = SATK*0.25
            SATK = SATK - SATK2
            WATK = WATK + SATK2
            SATK3 = SATK
            SATK = SDEF
            SDEF = SATK3
            WHP = WHP - (SATK - WDEF ) * 0.8 
            SHP = SHP - (WATK - SDEF ) * 0.8 
        elseif WSP < 0 && SSP < 0
            WHP = WHP - (SATK - WDEF ) * 0.8 
            SHP = SHP - (WATK - SDEF ) * 0.8 
        end
    elseif F == 0
        if WSP > 0 && SSP > 0
             WSP = WSP - 20
             SATK2 = SATK*0.25
             SATK = SATK - SATK2
             WATK = WATK + SATK2
             SATK3 = SATK
             SATK = SDEF
             SDEF = SATK3
             SHP = SHP - (WATK - SDEF ) * 0.8
             SSP = SSP - 20
             WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
             
        elseif WSP < 0 && SSP > 0
             SHP = SHP - (WATK - SDEF ) * 0.8 
             SSP = SSP - 20
             WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
             
            
        elseif WSP > 0 && SSP < 0
             WSP = WSP - 20
             SATK2 = SATK*0.25
             SATK = SATK - SATK2
             WATK = WATK + SATK2
             SATK3 = SATK
             SATK = SDEF
             SDEF = SATK3
             SHP = SHP - (WATK - SDEF ) * 0.8
             WHP = WHP - (SATK - WDEF ) * 0.8 
             
            
        elseif WSP < 0 && SSP < 0
            WHP = WHP - (SATK - WDEF ) * 0.8 
            SHP = SHP - (WATK - SDEF ) * 0.8 
        end 
    end
end
# Out:
# fight4 (generic function with 1 method)

# %%
WHP = wizard["HP"]
WSP = wizard["SP"]
WATK = wizard["ATK"]
WDEF = wizard["DEF"]
SHP = swordman["HP"]
SSP = swordman["SP"]
SATK = swordman["ATK"]
SDEF = swordman["DEF"]
x = [0,1]
y = [1,2,3,4]
for i in 1:20
    print("第",i,"次戰鬥-")
    F = rand(x)
    U = rand(y)
    if U == 1
        print("兩者皆為普攻-")
        if F == 1
             print("戰士先攻-")
             WHP = WHP - (SATK - WDEF ) * 0.8 
             SHP = SHP - (WATK - SDEF ) * 0.8 
        elseif F ==0
             print("法師先攻-")
             SHP = SHP - (WATK - SDEF ) * 0.8 
             WHP = WHP - (SATK - WDEF ) * 0.8 
        end
        if WHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        elseif SHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        end
        print("法師")
        print(WHP)
        print("戰士")
        print(SHP)
        
    elseif U == 2
        if F == 1
            
            if SSP > 0
               print("戰士發動技能-")
               print("戰士先攻-")
               SSP = SSP - 20
               WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
               SHP = SHP - (WATK - SDEF ) * 0.8 
            else
               print("兩者皆為普攻-")
               print("戰士先攻-")
               WHP = WHP - (SATK - WDEF ) * 0.8 
               SHP = SHP - (WATK - SDEF ) * 0.8 
            end
        elseif F == 0
            if SSP > 0
               print("戰士發動技能-")
               print("巫師先攻-")
               SHP = SHP - (WATK - SDEF ) * 0.8 
               SSP = SSP - 20
               WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
            else
               print("兩者皆為普攻-")
               print("巫師先攻-")
               SHP = SHP - (WATK - SDEF ) * 0.8 
               WHP = WHP - (SATK - WDEF ) * 0.8 
            end
        end
        if WHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        elseif SHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        end
        print("法師")
        print(WHP)
        print("戰士")
        print(SHP)
    elseif U == 3
        if F == 1
            if WSP > 0
                print("巫師發動技能-")
                print("戰士先攻-")
                WHP = WHP - (SATK - WDEF ) * 0.8 
                WSP = WSP - 20
                SATK2 = SATK*0.25
                SATK = SATK - SATK2
                WATK = WATK + SATK2
                SATK3 = SATK
                SATK = SDEF
                SDEF = SATK3
                SHP = SHP - (WATK - SDEF ) * 0.8 
            else
                print("兩者皆為普攻-")
                print("戰士先攻-")
                WHP = WHP - (SATK - WDEF ) * 0.8 
                SHP = SHP - (WATK - SDEF ) * 0.8
            end
       elseif F == 0
            if WSP > 0
                print("巫師發動技能-")
                print("巫師先攻-")
                WSP = WSP - 20
                SATK2 = SATK*0.25
                SATK = SATK - SATK2
                WATK = WATK + SATK2
                SATK3 = SATK
                SATK = SDEF
                SDEF = SATK3
                SHP = SHP - (WATK - SDEF ) * 0.8 
                WHP = WHP - (SATK - WDEF ) * 0.8 
            else
                print("兩者皆為普攻-")
                print("巫師先攻-")
                SHP = SHP - (WATK - SDEF ) * 0.8
                WHP = WHP - (SATK - WDEF ) * 0.8 
            end
        end
        if WHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        elseif SHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        end
        print("法師")
        print(WHP)
        print("戰士")
        print(SHP)
    elseif U == 4
        if F ==1  
            if WSP > 0 && SSP > 0
                print("兩者皆為發動技能-")
                print("戰士先攻-")
                SSP = SSP - 20
                WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
                WSP = WSP - 20
                SATK2 = SATK*0.25
                SATK = SATK - SATK2
                WATK = WATK + SATK2
                SATK3 = SATK
                SATK = SDEF
                SDEF = SATK3
                SHP = SHP - (WATK - SDEF ) * 0.8 
            elseif WSP <= 0 && SSP > 0
                print("戰士發動技能-")
                print("戰士先攻-")
                SSP = SSP - 20
                WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
                SHP = SHP - (WATK - SDEF ) * 0.8
            elseif WSP > 0 && SSP <= 0
                print("巫師發動技能-")
                print("戰士先攻-")
                SHP = SHP - (WATK - SDEF ) * 0.8 
                WSP = WSP - 20
                SATK2 = SATK*0.25
                SATK = SATK - SATK2
                WATK = WATK + SATK2
                SATK3 = SATK
                SATK = SDEF
                SDEF = SATK3
                WHP = WHP - (SATK - WDEF ) * 0.8 
            elseif WSP <= 0 && SSP <= 0
                print("兩者皆為普攻-")
                print("戰士先攻-")
                WHP = WHP - (SATK - WDEF ) * 0.8 
                SHP = SHP - (WATK - SDEF ) * 0.8 
            end
        elseif F == 0
            if WSP > 0 && SSP > 0
                print("兩者皆為發動技能-")
                print("巫師先攻-")
                WSP = WSP - 20
                SATK2 = SATK*0.25
                SATK = SATK - SATK2
                WATK = WATK + SATK2
                SATK3 = SATK
                SATK = SDEF
                SDEF = SATK3
                SHP = SHP - (WATK - SDEF ) * 0.8
                SSP = SSP - 20
                WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
             
            elseif WSP <= 0 && SSP > 0
                print("戰士發動技能-")
                print("巫師先攻-")
                WHP = WHP - ((2*SATK) - WDEF ) * 0.8 
                SHP = SHP - (WATK - SDEF ) * 0.8 
                SSP = SSP - 20
             
            
            elseif WSP > 0 && SSP <= 0
                print("巫師發動技能-")
                print("巫師先攻-")
                WSP = WSP - 20
                SATK2 = SATK*0.25
                SATK = SATK - SATK2
                WATK = WATK + SATK2
                SATK3 = SATK
                SATK = SDEF
                SDEF = SATK3
                SHP = SHP - (WATK - SDEF ) * 0.8
                WHP = WHP - (SATK - WDEF ) * 0.8 
             
            
            elseif WSP <= 0 && SSP <= 0
                print("兩者皆為普攻-")
                print("巫師先攻-")
                WHP = WHP - (SATK - WDEF ) * 0.8 
                SHP = SHP - (WATK - SDEF ) * 0.8 
            end 
        end
        if WHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        elseif SHP <= 0 
            print("法師")
            print(WHP)
            print("戰士")
            print(SHP)
            break
        end
        print("法師")
        print(WHP)
        print("戰士")
        print(SHP)
    end
     
end
# Out:
# 第1次戰鬥-兩者皆為普攻-法師先攻-法師80.0戰士80.0第2次戰鬥-戰士發動技能-戰士先攻-法師32.0戰士60.0第3次戰鬥-兩者皆為普攻-法師先攻-法師12.0戰士40.0第4次戰鬥-巫師發動技能-戰士先攻-法師-8.0戰士14.0
